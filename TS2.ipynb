# %%
import pandas as pd

# %%
df = pd.read_csv('Fact.FactPlanningMeasures.csv')

# %%
df.head()
# Out:
#   Time.[Month] Customer.[Account]     Product.[SKU] Version.[Version Name]  \
# 0   01-01-2016            Walmart            KitKat     CurrentWorkingView
# 1   01-01-2016            Walmart      Butterfinger     CurrentWorkingView
# 2   01-01-2016            Walmart            Crunch     CurrentWorkingView
# 3   01-01-2016            Walmart            Gerber     CurrentWorkingView
# 4   01-01-2016            Walmart  Gerber Graduates     CurrentWorkingView
#
#    Budget  Channel Inv  Forecast  Shipment  Consumption
# 0   13453      15633.0   19852.0    6080.0      10580.0
# 1   10460      19955.0   14551.0   10413.0      21522.0
# 2    8298      14501.0    2533.0     680.0      13220.0
# 3   20448       6004.0   20909.0   10851.0       2173.0
# 4   15657       3999.0   27628.0   22195.0       9452.0

# %%
new_df = df[df['Customer.[Account]'] == 'Walmart']

# %%
new_df.shape
# Out:
# (2940, 9)

# %%
df['Customer.[Account]'].nunique()
# Out:
# 6

# %%
new_df.head()
# Out:
#   Time.[Month] Customer.[Account]     Product.[SKU] Version.[Version Name]  \
# 0   01-01-2016            Walmart            KitKat     CurrentWorkingView
# 1   01-01-2016            Walmart      Butterfinger     CurrentWorkingView
# 2   01-01-2016            Walmart            Crunch     CurrentWorkingView
# 3   01-01-2016            Walmart            Gerber     CurrentWorkingView
# 4   01-01-2016            Walmart  Gerber Graduates     CurrentWorkingView
#
#    Budget  Channel Inv  Forecast  Shipment  Consumption
# 0   13453      15633.0   19852.0    6080.0      10580.0
# 1   10460      19955.0   14551.0   10413.0      21522.0
# 2    8298      14501.0    2533.0     680.0      13220.0
# 3   20448       6004.0   20909.0   10851.0       2173.0
# 4   15657       3999.0   27628.0   22195.0       9452.0

# %%
new_df['Product.[SKU]'].nunique()
# Out:
# 35

# %%
df['Product.[SKU]'].value_counts()
# Out:
# Milo                504
# Horlicks            504
# Crunch              504
# Soulfull            504
# DelMonte            504
# Doritos             504
# FabBox              504
# Dairymilk           504
# Lays                504
# Snickers            504
# Lipton              504
# Threptin            504
# Hersheys            504
# Jabsons             504
# Kelloggs            504
# Nutella             504
# Nestea              504
# Bingo               504
# Firstbites          504
# UrbanPlatter        504
# FunFoods            504
# Cornitos            504
# Cerelac             504
# Bagrrys             504
# Farex               504
# Boost               504
# Kissan              504
# YogaBar             504
# Gerber Graduates    504
# GoodDiet            504
# Kwality             504
# KitKat              504
# Butterfinger        504
# Gerber              504
# Quakers             504
# Name: Product.[SKU], dtype: int64

# %%
n_new_df = new_df[new_df['Product.[SKU]'] == 'Gerber Graduates']

# %%
n_new_df.shape
# Out:
# (84, 9)

# %%
n_new_df.head()
# Out:
#     Time.[Month] Customer.[Account]     Product.[SKU] Version.[Version Name]  \
# 4     01-01-2016            Walmart  Gerber Graduates     CurrentWorkingView
# 214   02-01-2016            Walmart  Gerber Graduates     CurrentWorkingView
# 424   03-01-2016            Walmart  Gerber Graduates     CurrentWorkingView
# 634   04-01-2016            Walmart  Gerber Graduates     CurrentWorkingView
# 863   05-01-2016            Walmart  Gerber Graduates     CurrentWorkingView
#
#      Budget  Channel Inv  Forecast  Shipment  Consumption
# 4     15657       3999.0   27628.0   22195.0       9452.0
# 214   15989       9588.0   33011.0   22383.0      23484.0
# 424    2391       6378.0   19856.0   23846.0      22150.0
# 634    1583      16952.0    1357.0   10093.0      21324.0
# 863   22274      18343.0    4649.0    8783.0       4205.0

# %%
n_new_df.tail()
# Out:
#       Time.[Month] Customer.[Account]     Product.[SKU]  \
# 16594   08-01-2022            Walmart  Gerber Graduates
# 16804   09-01-2022            Walmart  Gerber Graduates
# 17014   10-01-2022            Walmart  Gerber Graduates
# 17224   11-01-2022            Walmart  Gerber Graduates
# 17434   12-01-2022            Walmart  Gerber Graduates
#
#       Version.[Version Name]  Budget  Channel Inv  Forecast  Shipment  \
# 16594     CurrentWorkingView   15129          NaN   17708.0       NaN
# 16804     CurrentWorkingView   21529          NaN   16128.0       NaN
# 17014     CurrentWorkingView   22229          NaN    8131.0       NaN
# 17224     CurrentWorkingView    7778          NaN   12900.0       NaN
# 17434     CurrentWorkingView    5590          NaN   11830.0       NaN
#
#        Consumption
# 16594          NaN
# 16804          NaN
# 17014          NaN
# 17224          NaN
# 17434          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17640 entries, 0 to 17639
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Time.[Month]            17640 non-null  object
#  1   Customer.[Account]      17640 non-null  object
#  2   Product.[SKU]           17640 non-null  object
#  3   Version.[Version Name]  17640 non-null  object
#  4   Budget                  17640 non-null  int64
#  5   Channel Inv             11550 non-null  float64
#  6   Forecast                17495 non-null  float64
#  7   Shipment                11550 non-null  float64
#  8   Consumption             11550 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
ts_df = n_new_df[['Time.[Month]', 'Forecast']]

# %%
ts_df = ts_df.set_index('Time.[Month]')

# %%
ts_df.head()
# Out:
#               Forecast
# Time.[Month]
# 01-01-2016     27628.0
# 02-01-2016     33011.0
# 03-01-2016     19856.0
# 04-01-2016      1357.0
# 05-01-2016      4649.0

# %%
ts_df.tail()
# Out:
#               Forecast
# Time.[Month]
# 08-01-2022     17708.0
# 09-01-2022     16128.0
# 10-01-2022      8131.0
# 11-01-2022     12900.0
# 12-01-2022     11830.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
plt.ylabel('Forecast')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.plot(ts_df.index, ts_df['Forecast'], )

# %%
ts_df = ts_df.set_index(pd.to_datetime(ts_df.index))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)})

# %%
ts_df['Forecast'].plot(linewidth=0.5);

# %%
import warnings
import matplotlib.pyplot as plt
y = ts_df['Forecast']
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Weekly')
ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.set_ylabel('Orders')
ax.legend();

# %%
import statsmodels.api as sm

# graphs to show seasonal_decompose
def seasonal_decompose (y):
    decomposition = sm.tsa.seasonal_decompose(y, model='additive',extrapolate_trend='freq')
    fig = decomposition.plot()
    fig.set_size_inches(14,7)
    plt.show()

# %%
seasonal_decompose(y)
